# %% [markdown]
# ### **1. Data Preparation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %pip install matplotlib seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
url='https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'
df=pd.read_csv(url)

# Column 값들 소문자,공백은_로 통일하기
df.columns =df.columns.str.lower().str.replace(' ','_')

display(df.head())

# object 타입의 열 찾기
strings = list(df.dtypes[df.dtypes == 'str'].index)
print(strings)

# Column 살펴보기
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
# 시각화 하기
# %matplotlib inline

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(df.msrp, bins=50, ax=axes[0])
axes[0].set_title('MSRP 전체 분포')
axes[0].set_xlabel('MSRP')

sns.histplot(df.msrp[df.msrp < 100000], bins=50, ax=axes[1])
axes[1].set_title('MSRP 100000 이하 분포')
axes[1].set_xlabel('MSRP')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\오소민\AppData\Local\Temp\ipykernel_10268\2526875912.py:14: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\오소민\AppData\Local\Temp\ipykernel_10268\2526875912.py:14: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\오소민\AppData\Local\Temp\ipykernel_10268\2526875912.py:14: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\오소민\AppData\Local\Temp\ipykernel_10268\2526875912.py:14: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\오소민\AppData\Local\Temp\ipykernel_10268\2526875912.py:14: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
