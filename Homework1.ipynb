# %% [markdown]
# #### Q1.Pandas Version

# %%
import pandas as pd
print(pd.__version__)

url = "https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv"
df = pd.read_csv(url)
df.head()
# Out:
# 3.0.5
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# ...

# %% [markdown]
# #### **Q2.Records count**

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# #### **Q3. Fuel types**

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline    6913
# Diesel      2053
# Hybrid      1034
# Name: count, dtype: int64

# %% [markdown]
# #### **Q4. Missing values**

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# #### **Q5. Max fuel efficiency**

# %%
max(df.loc[df['origin']=='Asia','fuel_efficiency_mpg'])
# Out:
# 41.2

# %% [markdown]
# #### **Q6. Median value of horsepower**

# %%
print(df['horsepower'].median()) 
print(df['horsepower'].mode())

horsepower_mode = df['horsepower'].mode()[0]
df['horsepower'] = df['horsepower'].fillna(horsepower_mode)

print(df['horsepower'].median())
# Out:
# 254.0
# 0    252.0
# Name: horsepower, dtype: float64
# 252.0

# %% [markdown]
# #### **Q7. Sum of weights**

# %%
df_asia=df[df['origin']=='Asia']
df_asia[['vehicle_weight','model_year']]

# loc vs iloc
print(df_asia[['vehicle_weight','model_year']].iloc[:7,:])

X=df_asia[['vehicle_weight','model_year']].iloc[:7].values

import numpy as np 

XTX = X.T @ X

XTX_inv=np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = XTX_inv @ X.T @ y

print(w.sum())
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019
# 0.36919696904925486
